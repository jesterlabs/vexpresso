# %% [markdown]
# # Querying Pokemon using text and images with CLIP embeddings

# %% [markdown]
# ## In this walkthrough, we will be using a small dataset of Pokemon images and clip to embed

# %%
import json
import pandas as pd
import numpy as np
import daft
import vexpresso
from vexpresso.utils import ResourceRequest

# %% [markdown]
# ### Lets look at the Data: from https://github.com/Purukitto/pokemon-data.json

# %%
with open("./data/pokedex.json", 'r') as f:
    stuff = json.load(f)

df = pd.DataFrame(stuff)

# %%
df.head(10)
# Out:
#    id                                               name             type  \
# 0   1  {'english': 'Bulbasaur', 'japanese': 'フシギダネ', ...  [Grass, Poison]
# 1   2  {'english': 'Ivysaur', 'japanese': 'フシギソウ', 'c...  [Grass, Poison]
# 2   3  {'english': 'Venusaur', 'japanese': 'フシギバナ', '...  [Grass, Poison]
# 3   4  {'english': 'Charmander', 'japanese': 'ヒトカゲ', ...           [Fire]
# 4   5  {'english': 'Charmeleon', 'japanese': 'リザード', ...           [Fire]
# 5   6  {'english': 'Charizard', 'japanese': 'リザードン', ...   [Fire, Flying]
# 6   7  {'english': 'Squirtle', 'japanese': 'ゼニガメ', 'c...          [Water]
# 7   8  {'english': 'Wartortle', 'japanese': 'カメール', '...          [Water]
# 8   9  {'english': 'Blastoise', 'japanese': 'カメックス', ...          [Water]
# 9  10  {'english': 'Caterpie', 'japanese': 'キャタピー', '...            [Bug]
#
#                                                 base              species  \
# 0  {'HP': 45, 'Attack': 49, 'Defense': 49, 'Sp. A...         Seed Pokémon
# 1  {'HP': 60, 'Attack': 62, 'Defense': 63, 'Sp. A...         Seed Pokémon
# 2  {'HP': 80, 'Attack': 82, 'Defense': 83, 'Sp. A...         Seed Pokémon
# 3  {'HP': 39, 'Attack': 52, 'Defense': 43, 'Sp. A...       Lizard Pokémon
# 4  {'HP': 58, 'Attack': 64, 'Defense': 58, 'Sp. A...        Flame Pokémon
# 5  {'HP': 78, 'Attack': 84, 'Defense': 78, 'Sp. A...        Flame Pokémon
# 6  {'HP': 44, 'Attack': 48, 'Defense': 65, 'Sp. A...  Tiny Turtle Pokémon
# 7  {'HP': 59, 'Attack': 63, 'Defense': 80, 'Sp. A...       Turtle Pokémon
# 8  {'HP': 79, 'Attack': 83, 'Defense': 100, 'Sp. ...    Shellfish Pokémon
# 9  {'HP': 45, 'Attack': 30, 'Defense': 35, 'Sp. A...         Worm Pokémon
#
#                                          description  \
# 0  Bulbasaur can be seen napping in bright sunlig...
# 1  There is a bud on this Pokémon’s back. To supp...
# 2  There is a large flower on Venusaur’s back. Th...
# 3  The flame that burns at the tip of its tail is...
# 4  Charmeleon mercilessly destroys its foes using...
# 5  Charizard flies around the sky in search of po...
# 6  Squirtle’s shell is not merely used for protec...
# 7  Its tail is large and covered with a rich, thi...
# 8  Blastoise has water spouts that protrude from ...
# 9  Its body is soft and weak. In nature, its perp...
#
#                                            evolution  \
# 0                      {'next': [['2', 'Level 16']]}
# 1  {'prev': ['1', 'Level 16'], 'next': [['3', 'Le...
# 2                        {'prev': ['2', 'Level 32']}
# 3                      {'next': [['5', 'Level 16']]}
# 4  {'prev': ['4', 'Level 16'], 'next': [['6', 'Le...
# 5                        {'prev': ['5', 'Level 36']}
# 6                      {'next': [['8', 'Level 16']]}
# 7  {'prev': ['7', 'Level 16'], 'next': [['9', 'Le...
# 8                        {'prev': ['8', 'Level 36']}
# 9                      {'next': [['11', 'Level 7']]}
#
#                                              profile  \
# 0  {'height': '0.7 m', 'weight': '6.9 kg', 'egg':...
# 1  {'height': '1 m', 'weight': '13 kg', 'egg': ['...
# 2  {'height': '2 m', 'weight': '100 kg', 'egg': [...
# 3  {'height': '0.6 m', 'weight': '8.5 kg', 'egg':...
# 4  {'height': '1.1 m', 'weight': '19 kg', 'egg': ...
# 5  {'height': '1.7 m', 'weight': '90.5 kg', 'egg'...
# 6  {'height': '0.5 m', 'weight': '9 kg', 'egg': [...
# 7  {'height': '1 m', 'weight': '22.5 kg', 'egg': ...
# 8  {'height': '1.6 m', 'weight': '85.5 kg', 'egg'...
# 9  {'height': '0.3 m', 'weight': '2.9 kg', 'egg':...
#
#                                                image
# 0  {'sprite': 'https://raw.githubusercontent.com/...
# 1  {'sprite': 'https://raw.githubusercontent.com/...
# 2  {'sprite': 'https://raw.githubusercontent.com/...
# 3  {'sprite': 'https://raw.githubusercontent.com/...
# 4  {'sprite': 'https://raw.githubusercontent.com/...
# 5  {'sprite': 'https://raw.githubusercontent.com/...
# 6  {'sprite': 'https://raw.githubusercontent.com/...
# 7  {'sprite': 'https://raw.githubusercontent.com/...
# 8  {'sprite': 'https://raw.githubusercontent.com/...
# 9  {'sprite': 'https://raw.githubusercontent.com/...

# %% [markdown]
# #### Because this is a simple example, lets only use the first 151 Pokemon

# %%
df = df.iloc[:151]

# %%
df.iloc[0]["image"]
# Out:
# {'sprite': 'https://raw.githubusercontent.com/Purukitto/pokemon-data.json/master/images/pokedex/sprites/001.png',
#  'thumbnail': 'https://raw.githubusercontent.com/Purukitto/pokemon-data.json/master/images/pokedex/thumbnails/001.png',
#  'hires': 'https://raw.githubusercontent.com/Purukitto/pokemon-data.json/master/images/pokedex/hires/001.png'}

# %%
from PIL import Image
import requests

im = Image.open(requests.get("https://raw.githubusercontent.com/Purukitto/pokemon-data.json/master/images/pokedex/thumbnails/001.png", stream=True).raw)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=100x100>

# %% [markdown]
# ### Super simple download function!

# %%
def download_images(images, image_type):
    return [Image.open(requests.get(im["thumbnail"], stream=True).raw).convert(image_type) for im in images]

# %% [markdown]
# ### Create the collection, and use a custom transformation function to download images.

# %%
collection = vexpresso.create(data=df, backend="ray")
# Out:
# 2023-06-07 15:12:53.837 | INFO     | daft.context:runner:80 - Using PyRunner

# %% [markdown]
# #### For the call below, we want to pass in the image dictionaries in the column `image`, but we also want to specify `image_type` to be RGB

# %%
collection = collection.apply(download_images, collection["image"], image_type="RGB", to="downloaded_image").execute()

# %%
collection.show(5)
# Out:
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# |      id | name                                                                 | type                | base                                                                                                    | species        | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]     | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8           | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             |
# +=========+======================================================================+=====================+=========================================================================================================+================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+
# |       1 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 49,                                                                                          | Seed Pokémon   | Bulbasaur can be     | {'next': [['2',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 0 | <PIL.Image.Image   |
# |         | '妙蛙种子',                                                          |                     | 'Defense': 49, 'HP':                                                                                    |                | seen napping in      | 'Level 16']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     |
# |         | 'english':                                                           |                     | 45, 'Sp. Attack':                                                                                       |                | bright sunlight.     | 'prev': None}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    |
# |         | 'Bulbasaur',                                                         |                     | 65,...                                                                                                  |                | There i...           |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       |
# |         | 'french': 'Bu...                                                     |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# |       2 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 62,                                                                                          | Seed Pokémon   | There is a bud on    | {'next': [['3',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 1 | <PIL.Image.Image   |
# |         | '妙蛙草', 'english':                                                 |                     | 'Defense': 63, 'HP':                                                                                    |                | this Pokémon’s back. | 'Level 32']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     |
# |         | 'Ivysaur', 'french':                                                 |                     | 60, 'Sp. Attack':                                                                                       |                | To support its       | 'prev': ['1', 'Level                                              | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    |
# |         | 'Herbi...                                                            |                     | 80,...                                                                                                  |                | wei...               | 16']}                                                             | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       |
# |         |                                                                      |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# |       3 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 82,                                                                                          | Seed Pokémon   | There is a large     | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 2 | <PIL.Image.Image   |
# |         | '妙蛙花', 'english':                                                 |                     | 'Defense': 83, 'HP':                                                                                    |                | flower on Venusaur’s | 'prev': ['2', 'Level                                              | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     |
# |         | 'Venusaur',                                                          |                     | 80, 'Sp. Attack':                                                                                       |                | back. The flower     | 32']}                                                             | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    |
# |         | 'french': 'Flor...                                                   |                     | 100...                                                                                                  |                | is...                |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       |
# |         |                                                                      |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# |       4 | {'chinese':                                                          | ['Fire']            | {'Attack': 52,                                                                                          | Lizard Pokémon | The flame that burns | {'next': [['5',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 3 | <PIL.Image.Image   |
# |         | '小火龙', 'english':                                                 |                     | 'Defense': 43, 'HP':                                                                                    |                | at the tip of its    | 'Level 16']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     |
# |         | 'Charmander',                                                        |                     | 39, 'Sp. Attack':                                                                                       |                | tail is an           | 'prev': None}                                                     | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    |
# |         | 'french': 'Sa...                                                     |                     | 60,...                                                                                                  |                | indicat...           |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# |       5 | {'chinese':                                                          | ['Fire']            | {'Attack': 64,                                                                                          | Flame Pokémon  | Charmeleon           | {'next': [['6',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 4 | <PIL.Image.Image   |
# |         | '火恐龙', 'english':                                                 |                     | 'Defense': 58, 'HP':                                                                                    |                | mercilessly destroys | 'Level 36']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     |
# |         | 'Charmeleon',                                                        |                     | 58, 'Sp. Attack':                                                                                       |                | its foes using its   | 'prev': ['4', 'Level                                              | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    |
# |         | 'french': 'Re...                                                     |                     | 80,...                                                                                                  |                | sharp ...            | 16']}                                                             | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+
# (Showing first 5 rows)

# %% [markdown]
# ### Lets use a multimodal Clip Embeddings model to query images

# %%
from PIL import Image
import requests
from transformers import CLIPModel, CLIPProcessor, CLIPTokenizerFast
import torch
    
class ClipEmbeddingsFunction:
    def __init__(self):

        self.model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
        self.processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
        self.tokenizer = CLIPTokenizerFast.from_pretrained("openai/clip-vit-base-patch32")
        self.device = torch.device('cpu')

        if torch.cuda.is_available():
            self.device = torch.device('cuda')
            self.model = self.model.to(self.device)

    def __call__(self, inp, inp_type):
        if inp_type == "image":
            inputs = self.processor(images=inp, return_tensors="pt", padding=True)['pixel_values'].to(self.device)
            return self.model.get_image_features(inputs).detach().cpu().numpy()
        if inp_type == "text":
            inputs = self.tokenizer(inp, padding=True, return_tensors="pt")
            inputs["input_ids"] = inputs["input_ids"].to(self.device)
            inputs["attention_mask"] = inputs["attention_mask"].to(self.device)
            return self.model.get_text_features(**inputs).detach().cpu().numpy()

# %%
collection = collection.embed("downloaded_image", embedding_fn=ClipEmbeddingsFunction, inp_type="image", to="image_embeddings", resource_request = ResourceRequest(num_gpus=1)).execute()

# %% [markdown]
# #### This can also be done with the `apply` function

# %%
# collection = collection.apply(ClipEmbeddingsFunction, collection["downloaded_image"], inp_type="image", to="image_embeddings", resource_request = ResourceRequest(num_gpus=1)).execute()

# %%
collection.show(5)
# Out:
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# |      id | name                                                                 | type                | base                                                                                                    | species        | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]     | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8           | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             |
# +=========+======================================================================+=====================+=========================================================================================================+================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+
# |       1 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 49,                                                                                          | Seed Pokémon   | Bulbasaur can be     | {'next': [['2',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 0 | <PIL.Image.Image   | [ 4.89759803e-01   |
# |         | '妙蛙种子',                                                          |                     | 'Defense': 49, 'HP':                                                                                    |                | seen napping in      | 'Level 16']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -4.24020708e-01    |
# |         | 'english':                                                           |                     | 45, 'Sp. Attack':                                                                                       |                | bright sunlight.     | 'prev': None}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.33501816e-01    |
# |         | 'Bulbasaur',                                                         |                     | 65,...                                                                                                  |                | There i...           |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.79937...        |
# |         | 'french': 'Bu...                                                     |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# |       2 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 62,                                                                                          | Seed Pokémon   | There is a bud on    | {'next': [['3',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 1 | <PIL.Image.Image   | [ 5.51696718e-01   |
# |         | '妙蛙草', 'english':                                                 |                     | 'Defense': 63, 'HP':                                                                                    |                | this Pokémon’s back. | 'Level 32']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -2.17213750e-01    |
# |         | 'Ivysaur', 'french':                                                 |                     | 60, 'Sp. Attack':                                                                                       |                | To support its       | 'prev': ['1', 'Level                                              | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.51786947e-01    |
# |         | 'Herbi...                                                            |                     | 80,...                                                                                                  |                | wei...               | 16']}                                                             | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.67966...        |
# |         |                                                                      |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# |       3 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 82,                                                                                          | Seed Pokémon   | There is a large     | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 2 | <PIL.Image.Image   | [ 5.00680149e-01   |
# |         | '妙蛙花', 'english':                                                 |                     | 'Defense': 83, 'HP':                                                                                    |                | flower on Venusaur’s | 'prev': ['2', 'Level                                              | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -2.25727186e-02    |
# |         | 'Venusaur',                                                          |                     | 80, 'Sp. Attack':                                                                                       |                | back. The flower     | 32']}                                                             | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.24810177e-01    |
# |         | 'french': 'Flor...                                                   |                     | 100...                                                                                                  |                | is...                |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.53230...        |
# |         |                                                                      |                     |                                                                                                         |                |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# |       4 | {'chinese':                                                          | ['Fire']            | {'Attack': 52,                                                                                          | Lizard Pokémon | The flame that burns | {'next': [['5',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 3 | <PIL.Image.Image   | [ 2.63256997e-01   |
# |         | '小火龙', 'english':                                                 |                     | 'Defense': 43, 'HP':                                                                                    |                | at the tip of its    | 'Level 16']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -3.21479112e-01    |
# |         | 'Charmander',                                                        |                     | 39, 'Sp. Attack':                                                                                       |                | tail is an           | 'prev': None}                                                     | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.97793350e-01    |
# |         | 'french': 'Sa...                                                     |                     | 60,...                                                                                                  |                | indicat...           |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | 7.18055...         |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# |       5 | {'chinese':                                                          | ['Fire']            | {'Attack': 64,                                                                                          | Flame Pokémon  | Charmeleon           | {'next': [['6',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 4 | <PIL.Image.Image   | [ 2.63801932e-01   |
# |         | '火恐龙', 'english':                                                 |                     | 'Defense': 58, 'HP':                                                                                    |                | mercilessly destroys | 'Level 36']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -2.73643553e-01    |
# |         | 'Charmeleon',                                                        |                     | 58, 'Sp. Attack':                                                                                       |                | its foes using its   | 'prev': ['4', 'Level                                              | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.89278418e-01    |
# |         | 'french': 'Re...                                                     |                     | 80,...                                                                                                  |                | sharp ...            | 16']}                                                             | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | -6.30961...        |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+----------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+
# (Showing first 5 rows)

# %% [markdown]
# ### Query Images with text

# %% [markdown]
# #### Querying for red pokemon

# %%
red_pokemon = collection.query(
                        "image_embeddings",
                        query="Fire Pokemon that has red and orange skin and looks like a lizard",
                        k=10,
                        inp_type="text").execute()
red_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      id | name                                                                 | type              | base                                                                                                    | species          | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   |   image_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]   | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8             | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             |                  Float64 |
# +=========+======================================================================+===================+=========================================================================================================+==================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+==========================+
# |       5 | {'chinese':                                                          | ['Fire']          | {'Attack': 64,                                                                                          | Flame Pokémon    | Charmeleon           | {'next': [['6',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 4 | <PIL.Image.Image   | [ 2.63801932e-01   |                 0.337978 |
# |         | '火恐龙', 'english':                                                 |                   | 'Defense': 58, 'HP':                                                                                    |                  | mercilessly destroys | 'Level 36']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -2.73643553e-01    |                          |
# |         | 'Charmeleon',                                                        |                   | 58, 'Sp. Attack':                                                                                       |                  | its foes using its   | 'prev': ['4', 'Level                                              | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.89278418e-01    |                          |
# |         | 'french': 'Re...                                                     |                   | 80,...                                                                                                  |                  | sharp ...            | 16']}                                                             | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | -6.30961...        |                          |
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |     126 | {'chinese':                                                          | ['Fire']          | {'Attack': 95,                                                                                          | Spitfire Pokémon | The hotter the       | {'next': [['467',                                                 | {'ability': [['Flame                                                                                          | {'hires': 'https://r                                 |               125 | <PIL.Image.Image   | [ 2.22252816e-01   |                 0.33327  |
# |         | '鸭嘴火兽',                                                          |                   | 'Defense': 57, 'HP':                                                                                    |                  | place, the better    | 'trade holding                                                    | Body', 'false'],                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 2.62143224e-01     |                          |
# |         | 'english': 'Magmar',                                                 |                   | 65, 'Sp. Attack':                                                                                       |                  | they feel. Magmar in | Magmarizer']],                                                    | ['Vital Spirit',                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.05505265e-01    |                          |
# |         | 'french': 'Magma...                                                  |                   | 100...                                                                                                  |                  | Alo...               | 'prev': [...                                                      | 't...                                                                                                         |                                                      |                   | 0x7FD8490...       | -2.00592...        |                          |
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |       4 | {'chinese':                                                          | ['Fire']          | {'Attack': 52,                                                                                          | Lizard Pokémon   | The flame that burns | {'next': [['5',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 3 | <PIL.Image.Image   | [ 2.63256997e-01   |                 0.325211 |
# |         | '小火龙', 'english':                                                 |                   | 'Defense': 43, 'HP':                                                                                    |                  | at the tip of its    | 'Level 16']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -3.21479112e-01    |                          |
# |         | 'Charmander',                                                        |                   | 39, 'Sp. Attack':                                                                                       |                  | tail is an           | 'prev': None}                                                     | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.97793350e-01    |                          |
# |         | 'french': 'Sa...                                                     |                   | 60,...                                                                                                  |                  | indicat...           |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | 7.18055...         |                          |
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      99 | {'chinese':                                                          | ['Water']         | {'Attack': 130,                                                                                         | Pincer Pokémon   | Kingler has an       | {'next': None,                                                    | {'ability': [['Hyper                                                                                          | {'hires': 'https://r                                 |                98 | <PIL.Image.Image   | [ 4.06841487e-01   |                 0.304639 |
# |         | '巨钳蟹', 'english':                                                 |                   | 'Defense': 115,                                                                                         |                  | enormous, oversized  | 'prev': ['98',                                                    | Cutter', 'false'],                                                                                            | aw.githubusercontent                                 |                   | image mode=RGB     | -9.53320935e-02    |                          |
# |         | 'Kingler', 'french':                                                 |                   | 'HP': 55, 'Sp.                                                                                          |                  | claw. It waves this  | 'Level 28']}                                                      | ['Shell Armor', '...                                                                                          | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.69418991e-01    |                          |
# |         | 'Krabb...                                                            |                   | Attack': 5...                                                                                           |                  | hu...                |                                                                   |                                                                                                               |                                                      |                   | 0x7FD8490...       | -4.74716...        |                          |
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      37 | {'chinese': '六尾',                                                  | ['Fire']          | {'Attack': 41,                                                                                          | Fox Pokémon      | It manipulates balls | {'next': [['38',                                                  | {'ability': [['Flash                                                                                          | {'hires': 'https://r                                 |                36 | <PIL.Image.Image   | [ 2.28633150e-01   |                 0.302276 |
# |         | 'english': 'Vulpix',                                                 |                   | 'Defense': 40, 'HP':                                                                                    |                  | of fire to catch its | 'use Fire Stone']],                                               | Fire', 'false'],                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -2.84951329e-02    |                          |
# |         | 'french':                                                            |                   | 38, 'Sp. Attack':                                                                                       |                  | prey. If you ra...   | 'prev': None}                                                     | ['Drought',                                                                                                   | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.60699019e-02    |                          |
# |         | 'Goupix'...                                                          |                   | 50,...                                                                                                  |                  |                      |                                                                   | 'true']...                                                                                                    |                                                      |                   | 0x7FD8490...       | -7.61359...        |                          |
# +---------+----------------------------------------------------------------------+-------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# (Showing first 5 rows)

# %%
red_pokemon = collection.query("image_embeddings", "Fire Pokemon that has red and orange skin and looks like a lizard", k=10, inp_type="text") \
                        .filter({"base.Attack":{"gte":60}}) \
                        .execute()
red_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      id | name                                                                 | type               | base                                                                                                    | species          | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   |   image_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]    | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8             | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             |                  Float64 |
# +=========+======================================================================+====================+=========================================================================================================+==================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+==========================+
# |       5 | {'chinese':                                                          | ['Fire']           | {'Attack': 64,                                                                                          | Flame Pokémon    | Charmeleon           | {'next': [['6',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 4 | <PIL.Image.Image   | [ 2.63801932e-01   |                 0.337978 |
# |         | '火恐龙', 'english':                                                 |                    | 'Defense': 58, 'HP':                                                                                    |                  | mercilessly destroys | 'Level 36']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -2.73643553e-01    |                          |
# |         | 'Charmeleon',                                                        |                    | 58, 'Sp. Attack':                                                                                       |                  | its foes using its   | 'prev': ['4', 'Level                                              | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.89278418e-01    |                          |
# |         | 'french': 'Re...                                                     |                    | 80,...                                                                                                  |                  | sharp ...            | 16']}                                                             | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | -6.30961...        |                          |
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |     126 | {'chinese':                                                          | ['Fire']           | {'Attack': 95,                                                                                          | Spitfire Pokémon | The hotter the       | {'next': [['467',                                                 | {'ability': [['Flame                                                                                          | {'hires': 'https://r                                 |               125 | <PIL.Image.Image   | [ 2.22252816e-01   |                 0.33327  |
# |         | '鸭嘴火兽',                                                          |                    | 'Defense': 57, 'HP':                                                                                    |                  | place, the better    | 'trade holding                                                    | Body', 'false'],                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 2.62143224e-01     |                          |
# |         | 'english': 'Magmar',                                                 |                    | 65, 'Sp. Attack':                                                                                       |                  | they feel. Magmar in | Magmarizer']],                                                    | ['Vital Spirit',                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.05505265e-01    |                          |
# |         | 'french': 'Magma...                                                  |                    | 100...                                                                                                  |                  | Alo...               | 'prev': [...                                                      | 't...                                                                                                         |                                                      |                   | 0x7FD8490...       | -2.00592...        |                          |
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      99 | {'chinese':                                                          | ['Water']          | {'Attack': 130,                                                                                         | Pincer Pokémon   | Kingler has an       | {'next': None,                                                    | {'ability': [['Hyper                                                                                          | {'hires': 'https://r                                 |                98 | <PIL.Image.Image   | [ 4.06841487e-01   |                 0.304639 |
# |         | '巨钳蟹', 'english':                                                 |                    | 'Defense': 115,                                                                                         |                  | enormous, oversized  | 'prev': ['98',                                                    | Cutter', 'false'],                                                                                            | aw.githubusercontent                                 |                   | image mode=RGB     | -9.53320935e-02    |                          |
# |         | 'Kingler', 'french':                                                 |                    | 'HP': 55, 'Sp.                                                                                          |                  | claw. It waves this  | 'Level 28']}                                                      | ['Shell Armor', '...                                                                                          | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.69418991e-01    |                          |
# |         | 'Krabb...                                                            |                    | Attack': 5...                                                                                           |                  | hu...                |                                                                   |                                                                                                               |                                                      |                   | 0x7FD8490...       | -4.74716...        |                          |
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |       6 | {'chinese':                                                          | ['Fire', 'Flying'] | {'Attack': 84,                                                                                          | Flame Pokémon    | Charizard flies      | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 5 | <PIL.Image.Image   | [ 4.23560083e-01   |                 0.300802 |
# |         | '喷火龙', 'english':                                                 |                    | 'Defense': 78, 'HP':                                                                                    |                  | around the sky in    | 'prev': ['5', 'Level                                              | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -1.84708834e-02    |                          |
# |         | 'Charizard',                                                         |                    | 78, 'Sp. Attack':                                                                                       |                  | search of powerful   | 36']}                                                             | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.60779077e-01    |                          |
# |         | 'french': 'Dra...                                                    |                    | 109...                                                                                                  |                  | oppo...              |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | 1.17379...         |                          |
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      58 | {'chinese':                                                          | ['Fire']           | {'Attack': 70,                                                                                          | Puppy Pokémon    | It has lived         | {'next': [['59',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                57 | <PIL.Image.Image   | [ 1.47529796e-01   |                 0.29927  |
# |         | '卡蒂狗', 'english':                                                 |                    | 'Defense': 45, 'HP':                                                                                    |                  | alongside humans     | 'use Fire Stone']],                                               | [['Intimidate',                                                                                               | aw.githubusercontent                                 |                   | image mode=RGB     | 8.96822810e-02     |                          |
# |         | 'Growlithe',                                                         |                    | 55, 'Sp. Attack':                                                                                       |                  | since ages ago. Its  | 'prev': None}                                                     | 'false'], ['Flash                                                                                             | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.83102459e-01    |                          |
# |         | 'french': 'Can...                                                    |                    | 70,...                                                                                                  |                  | bones h...           |                                                                   | Fire', 'fal...                                                                                                |                                                      |                   | 0x7FD8490...       | -9.73911...        |                          |
# +---------+----------------------------------------------------------------------+--------------------+---------------------------------------------------------------------------------------------------------+------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# (Showing first 5 rows)

# %% [markdown]
# #### Querying for pokemon that look like plants

# %%
plant_pokemon = collection.query("image_embeddings", query="Pokemon that looks like a plant", k=10, inp_type="text") \
                        .execute()
plant_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      id | name                                                                 | type                 | base                                                                                                    | species            | description         | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   |   image_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]      | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8               | Utf8                | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             |                  Float64 |
# +=========+======================================================================+======================+=========================================================================================================+====================+=====================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+==========================+
# |      43 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 50,                                                                                          | Weed Pokémon       | Oddish searches for | {'next': [['44',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                42 | <PIL.Image.Image   | [ 5.41815817e-01   |                 0.344115 |
# |         | '走路草', 'english':                                                 |                      | 'Defense': 55, 'HP':                                                                                    |                    | fertile, nutrient-  | 'Level 21']],                                                     | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 6.55549765e-02     |                          |
# |         | 'Oddish', 'french':                                                  |                      | 45, 'Sp. Attack':                                                                                       |                    | rich soil, then     | 'prev': None}                                                     | 'false'], ['Run                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -7.30098933e-02    |                          |
# |         | 'Mysthe...                                                           |                      | 75,...                                                                                                  |                    | pla...              |                                                                   | Away', 'true...                                                                                               |                                                      |                   | 0x7FD8490...       | 2.40209...         |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |     103 | {'chinese':                                                          | ['Grass', 'Psychic'] | {'Attack': 95,                                                                                          | Coconut Pokémon    | Each of its three   | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |               102 | <PIL.Image.Image   | [ 3.58744919e-01   |                 0.335265 |
# |         | '椰蛋树', 'english':                                                 |                      | 'Defense': 85, 'HP':                                                                                    |                    | heads has its own   | 'prev': ['102', 'use                                              | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 3.56402434e-02     |                          |
# |         | 'Exeggutor',                                                         |                      | 95, 'Sp. Attack':                                                                                       |                    | thoughts. When they | Leaf Stone']}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.67346084e-01    |                          |
# |         | 'french': 'Noa...                                                    |                      | 125...                                                                                                  |                    | w...                |                                                                   | ['Harvest',                                                                                                   |                                                      |                   | 0x7FD8490...       | 6.22317...         |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                     |                                                                   | 'true'...                                                                                                     |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      69 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 75,                                                                                          | Flower Pokémon     | Bellsprout’s thin   | {'next': [['70',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                68 | <PIL.Image.Image   | [ 5.65115571e-01   |                 0.326029 |
# |         | '喇叭芽', 'english':                                                 |                      | 'Defense': 35, 'HP':                                                                                    |                    | and flexible body   | 'Level 21']],                                                     | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 4.09520417e-02     |                          |
# |         | 'Bellsprout',                                                        |                      | 50, 'Sp. Attack':                                                                                       |                    | lets it bend and    | 'prev': None}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -5.54089323e-02    |                          |
# |         | 'french': 'Ch...                                                     |                      | 70,...                                                                                                  |                    | sway...             |                                                                   | ['Gluttony',                                                                                                  |                                                      |                   | 0x7FD8490...       | -9.78566...        |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                     |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      11 | {'chinese':                                                          | ['Bug']              | {'Attack': 20,                                                                                          | Cocoon Pokémon     | Its hard shell      | {'next': [['12',                                                  | {'ability': [['Shed                                                                                           | {'hires': 'https://r                                 |                10 | <PIL.Image.Image   | [ 5.14270127e-01   |                 0.309279 |
# |         | '铁甲蛹', 'english':                                                 |                      | 'Defense': 55, 'HP':                                                                                    |                    | doesn’t crack a bit | 'Level 10']],                                                     | Skin', 'false']],                                                                                             | aw.githubusercontent                                 |                   | image mode=RGB     | -1.45562336e-01    |                          |
# |         | 'Metapod', 'french':                                                 |                      | 50, 'Sp. Attack':                                                                                       |                    | even if Pikipek     | 'prev': ['10',                                                    | 'egg': ['Bug'],                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.77716136e-01    |                          |
# |         | 'Chrys...                                                            |                      | 25,...                                                                                                  |                    | pecks ...           | 'Level 7']}                                                       | 'ge...                                                                                                        |                                                      |                   | 0x7FD8490...       | -4.14228...        |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      71 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 105,                                                                                         | Flycatcher Pokémon | Victreebel has a    | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                70 | <PIL.Image.Image   | [ 3.04084122e-01   |                 0.304989 |
# |         | '大食花', 'english':                                                 |                      | 'Defense': 65, 'HP':                                                                                    |                    | long vine that      | 'prev': ['70', 'use                                               | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -6.83281124e-02    |                          |
# |         | 'Victreebel',                                                        |                      | 80, 'Sp. Attack':                                                                                       |                    | extends from its    | Leaf Stone']}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.21880877e-01    |                          |
# |         | 'french': 'Em...                                                     |                      | 10...                                                                                                   |                    | head. Th...         |                                                                   | ['Gluttony',                                                                                                  |                                                      |                   | 0x7FD8490...       | 1.13124...         |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                     |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+---------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# (Showing first 5 rows)

# %% [markdown]
# #### Querying for Plant pokemon, but filtering out Bug pokemon

# %% [markdown]
# ##### We can use a custom filter or the built in `notcontains` method!

# %% [markdown]
# ```python
# # using custom filter
# def filter_by_type(typ, avoid_type):
#     return avoid_type not in typ
#
# filter_condition = {
#     "type": {
#         "custom": (filter_by_type, {"avoid_type":"Bug"})
#     }
# }
# ```

# %%
filter_condition = {
    "type": {
        "notcontains": "Bug"
    }
}

# %%
plant_pokemon = collection.query(
    "image_embeddings",
    query="Pokemon that looks like a plant",
    k=10,
    inp_type="text",
    filter_conditions=filter_condition
)
plant_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      id | name                                                                 | type                 | base                                                                                                    | species            | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   |   image_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]      | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8               | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             |                  Float64 |
# +=========+======================================================================+======================+=========================================================================================================+====================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+==========================+
# |      43 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 50,                                                                                          | Weed Pokémon       | Oddish searches for  | {'next': [['44',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                42 | <PIL.Image.Image   | [ 5.41815817e-01   |                 0.344115 |
# |         | '走路草', 'english':                                                 |                      | 'Defense': 55, 'HP':                                                                                    |                    | fertile, nutrient-   | 'Level 21']],                                                     | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 6.55549765e-02     |                          |
# |         | 'Oddish', 'french':                                                  |                      | 45, 'Sp. Attack':                                                                                       |                    | rich soil, then      | 'prev': None}                                                     | 'false'], ['Run                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -7.30098933e-02    |                          |
# |         | 'Mysthe...                                                           |                      | 75,...                                                                                                  |                    | pla...               |                                                                   | Away', 'true...                                                                                               |                                                      |                   | 0x7FD8490...       | 2.40209...         |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |     103 | {'chinese':                                                          | ['Grass', 'Psychic'] | {'Attack': 95,                                                                                          | Coconut Pokémon    | Each of its three    | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |               102 | <PIL.Image.Image   | [ 3.58744919e-01   |                 0.335265 |
# |         | '椰蛋树', 'english':                                                 |                      | 'Defense': 85, 'HP':                                                                                    |                    | heads has its own    | 'prev': ['102', 'use                                              | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 3.56402434e-02     |                          |
# |         | 'Exeggutor',                                                         |                      | 95, 'Sp. Attack':                                                                                       |                    | thoughts. When they  | Leaf Stone']}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.67346084e-01    |                          |
# |         | 'french': 'Noa...                                                    |                      | 125...                                                                                                  |                    | w...                 |                                                                   | ['Harvest',                                                                                                   |                                                      |                   | 0x7FD8490...       | 6.22317...         |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                      |                                                                   | 'true'...                                                                                                     |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      69 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 75,                                                                                          | Flower Pokémon     | Bellsprout’s thin    | {'next': [['70',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                68 | <PIL.Image.Image   | [ 5.65115571e-01   |                 0.326029 |
# |         | '喇叭芽', 'english':                                                 |                      | 'Defense': 35, 'HP':                                                                                    |                    | and flexible body    | 'Level 21']],                                                     | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | 4.09520417e-02     |                          |
# |         | 'Bellsprout',                                                        |                      | 50, 'Sp. Attack':                                                                                       |                    | lets it bend and     | 'prev': None}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -5.54089323e-02    |                          |
# |         | 'french': 'Ch...                                                     |                      | 70,...                                                                                                  |                    | sway...              |                                                                   | ['Gluttony',                                                                                                  |                                                      |                   | 0x7FD8490...       | -9.78566...        |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |      71 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 105,                                                                                         | Flycatcher Pokémon | Victreebel has a     | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                70 | <PIL.Image.Image   | [ 3.04084122e-01   |                 0.304989 |
# |         | '大食花', 'english':                                                 |                      | 'Defense': 65, 'HP':                                                                                    |                    | long vine that       | 'prev': ['70', 'use                                               | [['Chlorophyll',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -6.83281124e-02    |                          |
# |         | 'Victreebel',                                                        |                      | 80, 'Sp. Attack':                                                                                       |                    | extends from its     | Leaf Stone']}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.21880877e-01    |                          |
# |         | 'french': 'Em...                                                     |                      | 10...                                                                                                   |                    | head. Th...          |                                                                   | ['Gluttony',                                                                                                  |                                                      |                   | 0x7FD8490...       | 1.13124...         |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# |       3 | {'chinese':                                                          | ['Grass', 'Poison']  | {'Attack': 82,                                                                                          | Seed Pokémon       | There is a large     | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 2 | <PIL.Image.Image   | [ 5.00680149e-01   |                 0.302817 |
# |         | '妙蛙花', 'english':                                                 |                      | 'Defense': 83, 'HP':                                                                                    |                    | flower on Venusaur’s | 'prev': ['2', 'Level                                              | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -2.25727186e-02    |                          |
# |         | 'Venusaur',                                                          |                      | 80, 'Sp. Attack':                                                                                       |                    | back. The flower     | 32']}                                                             | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.24810177e-01    |                          |
# |         | 'french': 'Flor...                                                   |                      | 100...                                                                                                  |                    | is...                |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.53230...        |                          |
# |         |                                                                      |                      |                                                                                                         |                    |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                          |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+--------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+--------------------------+
# (Showing first 5 rows)

# %% [markdown]
# ### Averaging text and image embeddings

# %%
collection = collection.embed("description", embedding_fn=collection.embedding_functions["image_embeddings"], inp_type="text", to="text_embeddings", resource_request=ResourceRequest(num_gpus=0)).execute()

# %%
collection.show(10)
# Out:
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |      id | name                                                                 | type                | base                                                                                                    | species             | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   | text_embeddings   |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]     | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8                | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             | Python            |
# +=========+======================================================================+=====================+=========================================================================================================+=====================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+===================+
# |       1 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 49,                                                                                          | Seed Pokémon        | Bulbasaur can be     | {'next': [['2',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 0 | <PIL.Image.Image   | [ 4.89759803e-01   | [ 3.31286862e-02  |
# |         | '妙蛙种子',                                                          |                     | 'Defense': 49, 'HP':                                                                                    |                     | seen napping in      | 'Level 16']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -4.24020708e-01    | 1.27609372e-02    |
# |         | 'english':                                                           |                     | 45, 'Sp. Attack':                                                                                       |                     | bright sunlight.     | 'prev': None}                                                     | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.33501816e-01    | 2.14425027e-01    |
# |         | 'Bulbasaur',                                                         |                     | 65,...                                                                                                  |                     | There i...           |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.79937...        | -2.55547...       |
# |         | 'french': 'Bu...                                                     |                     |                                                                                                         |                     |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                   |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       2 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 62,                                                                                          | Seed Pokémon        | There is a bud on    | {'next': [['3',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 1 | <PIL.Image.Image   | [ 5.51696718e-01   | [ 1.62872076e-01  |
# |         | '妙蛙草', 'english':                                                 |                     | 'Defense': 63, 'HP':                                                                                    |                     | this Pokémon’s back. | 'Level 32']],                                                     | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -2.17213750e-01    | 2.45135635e-01    |
# |         | 'Ivysaur', 'french':                                                 |                     | 60, 'Sp. Attack':                                                                                       |                     | To support its       | 'prev': ['1', 'Level                                              | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.51786947e-01    | 1.79179892e-01    |
# |         | 'Herbi...                                                            |                     | 80,...                                                                                                  |                     | wei...               | 16']}                                                             | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.67966...        | -2.57794...       |
# |         |                                                                      |                     |                                                                                                         |                     |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                   |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       3 | {'chinese':                                                          | ['Grass', 'Poison'] | {'Attack': 82,                                                                                          | Seed Pokémon        | There is a large     | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 2 | <PIL.Image.Image   | [ 5.00680149e-01   | [ 2.63738811e-01  |
# |         | '妙蛙花', 'english':                                                 |                     | 'Defense': 83, 'HP':                                                                                    |                     | flower on Venusaur’s | 'prev': ['2', 'Level                                              | [['Overgrow',                                                                                                 | aw.githubusercontent                                 |                   | image mode=RGB     | -2.25727186e-02    | 6.09989241e-02    |
# |         | 'Venusaur',                                                          |                     | 80, 'Sp. Attack':                                                                                       |                     | back. The flower     | 32']}                                                             | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.24810177e-01    | 2.15104669e-02    |
# |         | 'french': 'Flor...                                                   |                     | 100...                                                                                                  |                     | is...                |                                                                   | ['Chlorophyll',                                                                                               |                                                      |                   | 0x7FD8490...       | -1.53230...        | -2.37138...       |
# |         |                                                                      |                     |                                                                                                         |                     |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                   |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       4 | {'chinese':                                                          | ['Fire']            | {'Attack': 52,                                                                                          | Lizard Pokémon      | The flame that burns | {'next': [['5',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 3 | <PIL.Image.Image   | [ 2.63256997e-01   | [-1.27095580e-01  |
# |         | '小火龙', 'english':                                                 |                     | 'Defense': 43, 'HP':                                                                                    |                     | at the tip of its    | 'Level 16']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -3.21479112e-01    | 4.29234356e-01    |
# |         | 'Charmander',                                                        |                     | 39, 'Sp. Attack':                                                                                       |                     | tail is an           | 'prev': None}                                                     | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.97793350e-01    | 1.60282314e-01    |
# |         | 'french': 'Sa...                                                     |                     | 60,...                                                                                                  |                     | indicat...           |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | 7.18055...         | -1.67987...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       5 | {'chinese':                                                          | ['Fire']            | {'Attack': 64,                                                                                          | Flame Pokémon       | Charmeleon           | {'next': [['6',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 4 | <PIL.Image.Image   | [ 2.63801932e-01   | [ 1.85636580e-01  |
# |         | '火恐龙', 'english':                                                 |                     | 'Defense': 58, 'HP':                                                                                    |                     | mercilessly destroys | 'Level 36']],                                                     | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -2.73643553e-01    | 1.61594719e-01    |
# |         | 'Charmeleon',                                                        |                     | 58, 'Sp. Attack':                                                                                       |                     | its foes using its   | 'prev': ['4', 'Level                                              | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -2.89278418e-01    | -5.96877858e-02   |
# |         | 'french': 'Re...                                                     |                     | 80,...                                                                                                  |                     | sharp ...            | 16']}                                                             | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | -6.30961...        | -1.22651...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       6 | {'chinese':                                                          | ['Fire', 'Flying']  | {'Attack': 84,                                                                                          | Flame Pokémon       | Charizard flies      | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 5 | <PIL.Image.Image   | [ 4.23560083e-01   | [ 2.91018039e-02  |
# |         | '喷火龙', 'english':                                                 |                     | 'Defense': 78, 'HP':                                                                                    |                     | around the sky in    | 'prev': ['5', 'Level                                              | [['Blaze', 'false'],                                                                                          | aw.githubusercontent                                 |                   | image mode=RGB     | -1.84708834e-02    | 4.93785799e-01    |
# |         | 'Charizard',                                                         |                     | 78, 'Sp. Attack':                                                                                       |                     | search of powerful   | 36']}                                                             | ['Solar Power',                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.60779077e-01    | -5.62904924e-02   |
# |         | 'french': 'Dra...                                                    |                     | 109...                                                                                                  |                     | oppo...              |                                                                   | 'true']]...                                                                                                   |                                                      |                   | 0x7FD8490...       | 1.17379...         | -1.45073...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       7 | {'chinese':                                                          | ['Water']           | {'Attack': 48,                                                                                          | Tiny Turtle Pokémon | Squirtle’s shell is  | {'next': [['8',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 6 | <PIL.Image.Image   | [ 3.47441792e-01   | [-2.39824951e-02  |
# |         | '杰尼龟', 'english':                                                 |                     | 'Defense': 65, 'HP':                                                                                    |                     | not merely used for  | 'Level 16']],                                                     | [['Torrent',                                                                                                  | aw.githubusercontent                                 |                   | image mode=RGB     | -2.36999214e-01    | 3.75539333e-01    |
# |         | 'Squirtle',                                                          |                     | 44, 'Sp. Attack':                                                                                       |                     | protection. The s... | 'prev': None}                                                     | 'false'], ['Rain                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.88795835e-01    | 2.53314823e-01    |
# |         | 'french': 'Cara...                                                   |                     | 50,...                                                                                                  |                     |                      |                                                                   | Dish', 'true']]...                                                                                            |                                                      |                   | 0x7FD8490...       | -2.66130...        | 2.00912...        |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       8 | {'chinese':                                                          | ['Water']           | {'Attack': 63,                                                                                          | Turtle Pokémon      | Its tail is large    | {'next': [['9',                                                   | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 7 | <PIL.Image.Image   | [ 2.42762655e-01   | [ 1.12402558e-01  |
# |         | '卡咪龟', 'english':                                                 |                     | 'Defense': 80, 'HP':                                                                                    |                     | and covered with a   | 'Level 36']],                                                     | [['Torrent',                                                                                                  | aw.githubusercontent                                 |                   | image mode=RGB     | -1.53857261e-01    | 3.62911820e-01    |
# |         | 'Wartortle',                                                         |                     | 59, 'Sp. Attack':                                                                                       |                     | rich, thick fur.     | 'prev': ['7', 'Level                                              | 'false'], ['Rain                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.93319798e-01    | -1.21998042e-02   |
# |         | 'french': 'Car...                                                    |                     | 65,...                                                                                                  |                     | The...               | 16']}                                                             | Dish', 'true']]...                                                                                            |                                                      |                   | 0x7FD8490...       | 1.01631...         | 9.26273...        |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |       9 | {'chinese':                                                          | ['Water']           | {'Attack': 83,                                                                                          | Shellfish Pokémon   | Blastoise has water  | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 8 | <PIL.Image.Image   | [ 4.11614865e-01   | [ 1.11632951e-01  |
# |         | '水箭龟', 'english':                                                 |                     | 'Defense': 100,                                                                                         |                     | spouts that protrude | 'prev': ['8', 'Level                                              | [['Torrent',                                                                                                  | aw.githubusercontent                                 |                   | image mode=RGB     | 9.17963684e-02     | 2.85135508e-01    |
# |         | 'Blastoise',                                                         |                     | 'HP': 79, 'Sp.                                                                                          |                     | from its shell. ...  | 36']}                                                             | 'false'], ['Rain                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.71524763e-01    | 2.70831525e-01    |
# |         | 'french': 'Tor...                                                    |                     | Attack': 85...                                                                                          |                     |                      |                                                                   | Dish', 'true']]...                                                                                            |                                                      |                   | 0x7FD8490...       | 9.62148...         | -1.79530...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# |      10 | {'chinese':                                                          | ['Bug']             | {'Attack': 30,                                                                                          | Worm Pokémon        | Its body is soft and | {'next': [['11',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 9 | <PIL.Image.Image   | [ 4.44074512e-01   | [ 7.61542469e-02  |
# |         | '绿毛虫', 'english':                                                 |                     | 'Defense': 35, 'HP':                                                                                    |                     | weak. In nature, its | 'Level 7']], 'prev':                                              | [['Shield Dust',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -1.23782754e-01    | 8.82237554e-02    |
# |         | 'Caterpie',                                                          |                     | 45, 'Sp. Attack':                                                                                       |                     | perpetual fate ...   | None}                                                             | 'false'], ['Run                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.02484691e-01    | 3.60970348e-01    |
# |         | 'french': 'Chen...                                                   |                     | 20,...                                                                                                  |                     |                      |                                                                   | Away', 'true...                                                                                               |                                                      |                   | 0x7FD8490...       | -4.87557...        | -2.34479...       |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+---------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+
# (Showing first 10 rows)

# %%
def combine_embeddings(text_embeddings, image_embeddings, text_embedding_weight = 0.25, image_embeddings_weight = 0.75):
    text_embeddings = np.stack(text_embeddings)
    image_embeddings = np.stack(image_embeddings)
    averaged = text_embedding_weight*text_embeddings + image_embeddings_weight*image_embeddings
    return [average for average in averaged]

# %%
collection = collection.apply(
    combine_embeddings,
    collection["text_embeddings"],
    collection["image_embeddings"],
    text_embedding_weight=0.5,
    image_embeddings_weight=0.5,
    to="combined_embeddings"
).execute()

# %%
red_pokemon = collection.query(
                        "image_embeddings",
                        query="Lizard Pokemon",
                        k=10,
                        inp_type="text",
                        embedding_fn=collection.embedding_functions["image_embeddings"]
                    ).execute()
red_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# |      id | name                                                                 | type                | base                                                                                                    | species           | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   | text_embeddings   | combined_embeddings   |   image_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]     | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8              | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             | Python            | Python                |                  Float64 |
# +=========+======================================================================+=====================+=========================================================================================================+===================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+===================+=======================+==========================+
# |      13 | {'chinese':                                                          | ['Bug', 'Poison']   | {'Attack': 35,                                                                                          | Hairy Bug Pokémon | Weedle has an        | {'next': [['14',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                12 | <PIL.Image.Image   | [ 4.46034700e-01   | [ 3.43946069e-01  | [ 3.94990385e-01      |                 0.29357  |
# |         | '独角虫', 'english':                                                 |                     | 'Defense': 30, 'HP':                                                                                    |                   | extremely acute      | 'Level 7']], 'prev':                                              | [['Shield Dust',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -2.77689368e-01    | 2.66475141e-01    | -5.60711324e-03       |                          |
# |         | 'Weedle', 'french':                                                  |                     | 40, 'Sp. Attack':                                                                                       |                   | sense of smell. It   | None}                                                             | 'false'], ['Run                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -1.40615523e-01    | 1.58195525e-01    | 8.79000127e-03        |                          |
# |         | 'Aspico...                                                           |                     | 20,...                                                                                                  |                   | is capab...          |                                                                   | Away', 'true...                                                                                               |                                                      |                   | 0x7FD8490...       | -1.80928...        | 1.99314...        | 9.19316...            |                          |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# |     130 | {'chinese':                                                          | ['Water', 'Flying'] | {'Attack': 125,                                                                                         | Atrocious Pokémon | The energy from      | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |               129 | <PIL.Image.Image   | [ 4.13414121e-01   | [ 1.31131142e-01  | [ 2.72272646e-01      |                 0.293366 |
# |         | '暴鲤龙', 'english':                                                 |                     | 'Defense': 79, 'HP':                                                                                    |                   | evolution stimulated | 'prev': ['129',                                                   | [['Intimidate',                                                                                               | aw.githubusercontent                                 |                   | image mode=RGB     | -2.34985411e-01    | 1.21554367e-01    | -5.67155220e-02       |                          |
# |         | 'Gyarados',                                                          |                     | 95, 'Sp. Attack':                                                                                       |                   | its brain cells      | 'Level 20']}                                                      | 'false'], ['Moxie',                                                                                           | .com/Purukitto/po...                                 |                   | size=100x100 at    | -4.84766424e-01    | -6.66615665e-02   | -2.75713980e-01       |                          |
# |         | 'french': 'Lévi...                                                   |                     | 60...                                                                                                   |                   | stro...              |                                                                   | 'true']],...                                                                                                  |                                                      |                   | 0x7FD8490...       | -8.90192...        | -1.79097...       | -1.34058...           |                          |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# |     112 | {'chinese':                                                          | ['Ground', 'Rock']  | {'Attack': 130,                                                                                         | Drill Pokémon     | Rhydon has a horn    | {'next': [['464',                                                 | {'ability':                                                                                                   | {'hires': 'https://r                                 |               111 | <PIL.Image.Image   | [ 2.91801870e-01   | [ 9.47697163e-02  | [ 1.93285793e-01      |                 0.291984 |
# |         | '钻角犀兽',                                                          |                     | 'Defense': 120,                                                                                         |                   | that serves as a     | 'trade holding                                                    | [['Lightning Rod',                                                                                            | aw.githubusercontent                                 |                   | image mode=RGB     | -1.35060623e-01    | 2.67461926e-01    | 6.62006512e-02        |                          |
# |         | 'english': 'Rhydon',                                                 |                     | 'HP': 105, 'Sp.                                                                                         |                   | drill. It is used    | Protector']],                                                     | 'false'], ['Rock                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.01871091e-01    | 2.06116125e-01    | -4.78774831e-02       |                          |
# |         | 'french': 'Rhino...                                                  |                     | Attack': ...                                                                                            |                   | for ...              | 'prev': ['...                                                     | Head', 'f...                                                                                                  |                                                      |                   | 0x7FD8490...       | 7.64096...         | 3.80288...        | 5.72192...            |                          |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# |     116 | {'chinese':                                                          | ['Water']           | {'Attack': 40,                                                                                          | Dragon Pokémon    | If Horsea senses     | {'next': [['117',                                                 | {'ability': [['Swift                                                                                          | {'hires': 'https://r                                 |               115 | <PIL.Image.Image   | [ 4.25695181e-01   | [ 2.20806196e-01  | [ 3.23250681e-01      |                 0.290683 |
# |         | '墨海马', 'english':                                                 |                     | 'Defense': 70, 'HP':                                                                                    |                   | danger, it will      | 'Level 32']],                                                     | Swim', 'false'],                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -3.43029678e-01    | -3.44575316e-01   | -3.43802512e-01       |                          |
# |         | 'Horsea', 'french':                                                  |                     | 30, 'Sp. Attack':                                                                                       |                   | reflexively spray a  | 'prev': None}                                                     | ['Sniper',                                                                                                    | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.02480817e-01    | 8.75981748e-02    | -1.07441321e-01       |                          |
# |         | 'Hypotr...                                                           |                     | 70,...                                                                                                  |                   | dens...              |                                                                   | 'false']...                                                                                                   |                                                      |                   | 0x7FD8490...       | -1.68781...        | -2.26003...       | -1.97392...           |                          |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# |     117 | {'chinese':                                                          | ['Water']           | {'Attack': 65,                                                                                          | Dragon Pokémon    | Seadra generates     | {'next': [['230',                                                 | {'ability':                                                                                                   | {'hires': 'https://r                                 |               116 | <PIL.Image.Image   | [ 1.60170138e-01   | [ 1.10654667e-01  | [ 1.35412395e-01      |                 0.29013  |
# |         | '海刺龙', 'english':                                                 |                     | 'Defense': 95, 'HP':                                                                                    |                   | whirlpools by        | 'trade holding                                                    | [['Poison Point',                                                                                             | aw.githubusercontent                                 |                   | image mode=RGB     | -1.47717446e-01    | 2.68111899e-02    | -6.04531281e-02       |                          |
# |         | 'Seadra', 'french':                                                  |                     | 55, 'Sp. Attack':                                                                                       |                   | spinning its body.   | Dragon Scale']],                                                  | 'false'], ['Sniper',                                                                                          | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.38658214e-01    | 2.41318569e-01    | -4.86698225e-02       |                          |
# |         | 'Hypocé...                                                           |                     | 95,...                                                                                                  |                   | The whi...           | 'prev':...                                                        | 'false...                                                                                                     |                                                      |                   | 0x7FD8490...       | -2.42029...        | -4.17511...       | -3.29770...           |                          |
# +---------+----------------------------------------------------------------------+---------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+--------------------------+
# (Showing first 5 rows)

# %%
red_pokemon = collection.query(
                        "combined_embeddings",
                        query="Lizard Pokemon",
                        k=10,
                        inp_type="text",
                        embedding_fn=collection.embedding_functions["image_embeddings"]
                    ).execute()
red_pokemon.show(5)
# Out:
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# |      id | name                                                                 | type                 | base                                                                                                    | species           | description          | evolution                                                         | profile                                                                                                       | image                                                |   vexpresso_index | downloaded_image   | image_embeddings   | text_embeddings   | combined_embeddings   |   combined_embeddings_score |
# |   Int64 | Struct[chinese: Utf8, english: Utf8, french: Utf8, japanese: Utf8]   | List[item:Utf8]      | Struct[Attack: Int64, Defense: Int64, HP: Int64, Sp. Attack: Int64, Sp. Defense: Int64, Speed: Int64]   | Utf8              | Utf8                 | Struct[next: List[item:List[item:Utf8]], prev: List[item:Utf8]]   | Struct[ability: List[item:List[item:Utf8]], egg: List[item:Utf8], gender: Utf8, height: Utf8, weight: Utf8]   | Struct[hires: Utf8, sprite: Utf8, thumbnail: Utf8]   |             Int64 | Python             | Python             | Python            | Python                |                     Float64 |
# +=========+======================================================================+======================+=========================================================================================================+===================+======================+===================================================================+===============================================================================================================+======================================================+===================+====================+====================+===================+=======================+=============================+
# |     130 | {'chinese':                                                          | ['Water', 'Flying']  | {'Attack': 125,                                                                                         | Atrocious Pokémon | The energy from      | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |               129 | <PIL.Image.Image   | [ 4.13414121e-01   | [ 1.31131142e-01  | [ 2.72272646e-01      |                    0.671281 |
# |         | '暴鲤龙', 'english':                                                 |                      | 'Defense': 79, 'HP':                                                                                    |                   | evolution stimulated | 'prev': ['129',                                                   | [['Intimidate',                                                                                               | aw.githubusercontent                                 |                   | image mode=RGB     | -2.34985411e-01    | 1.21554367e-01    | -5.67155220e-02       |                             |
# |         | 'Gyarados',                                                          |                      | 95, 'Sp. Attack':                                                                                       |                   | its brain cells      | 'Level 20']}                                                      | 'false'], ['Moxie',                                                                                           | .com/Purukitto/po...                                 |                   | size=100x100 at    | -4.84766424e-01    | -6.66615665e-02   | -2.75713980e-01       |                             |
# |         | 'french': 'Lévi...                                                   |                      | 60...                                                                                                   |                   | stro...              |                                                                   | 'true']],...                                                                                                  |                                                      |                   | 0x7FD8490...       | -8.90192...        | -1.79097...       | -1.34058...           |                             |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# |     140 | {'chinese':                                                          | ['Rock', 'Water']    | {'Attack': 80,                                                                                          | Shellfish Pokémon | This Pokémon became  | {'next': [['141',                                                 | {'ability': [['Swift                                                                                          | {'hires': 'https://r                                 |               139 | <PIL.Image.Image   | [ 5.04388213e-01   | [ 2.17316955e-01  | [ 3.60852599e-01      |                    0.659008 |
# |         | '化石盔', 'english':                                                 |                      | 'Defense': 90, 'HP':                                                                                    |                   | extinct everywhere,  | 'Level 40']],                                                     | Swim', 'false'],                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -1.73163936e-01    | 6.36452973e-01    | 2.31644511e-01        |                             |
# |         | 'Kabuto', 'french':                                                  |                      | 30, 'Sp. Attack':                                                                                       |                   | except in a few a... | 'prev': None}                                                     | ['Battle Armor',                                                                                              | .com/Purukitto/po...                                 |                   | size=100x100 at    | -6.89704418e-02    | -1.37192428e-01   | -1.03081435e-01       |                             |
# |         | 'Kabuto...                                                           |                      | 55,...                                                                                                  |                   |                      |                                                                   | 'f...                                                                                                         |                                                      |                   | 0x7FD8490...       | 2.62349...         | 2.07039...        | 1.41526...            |                             |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# |     149 | {'chinese': '快龙',                                                  | ['Dragon', 'Flying'] | {'Attack': 134,                                                                                         | Dragon Pokémon    | You’ll often hear    | {'next': None,                                                    | {'ability': [['Inner                                                                                          | {'hires': 'https://r                                 |               148 | <PIL.Image.Image   | [ 3.88334751e-01   | [ 3.31938058e-01  | [ 3.60136390e-01      |                    0.658508 |
# |         | 'english':                                                           |                      | 'Defense': 95, 'HP':                                                                                    |                   | tales of this        | 'prev': ['148',                                                   | Focus', 'false'],                                                                                             | aw.githubusercontent                                 |                   | image mode=RGB     | -1.53514117e-01    | 5.52040577e-01    | 1.99263230e-01        |                             |
# |         | 'Dragonite',                                                         |                      | 91, 'Sp. Attack':                                                                                       |                   | kindhearted Pokémon  | 'Level 55']}                                                      | ['Multiscale',                                                                                                | .com/Purukitto/po...                                 |                   | size=100x100 at    | -4.88508135e-01    | 1.61139786e-01    | -1.63684174e-01       |                             |
# |         | 'french': 'Drac...                                                   |                      | 10...                                                                                                   |                   | rescu...             |                                                                   | 'tr...                                                                                                        |                                                      |                   | 0x7FD8490...       | 3.95812...         | 7.28716...        | 5.62264...            |                             |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# |      26 | {'chinese': '雷丘',                                                  | ['Electric']         | {'Attack': 90,                                                                                          | Mouse Pokémon     | Because so many      | {'next': None,                                                    | {'ability':                                                                                                   | {'hires': 'https://r                                 |                25 | <PIL.Image.Image   | [ 3.21645945e-01   | [-1.18329093e-01  | [ 1.01658426e-01      |                    0.653126 |
# |         | 'english': 'Raichu',                                                 |                      | 'Defense': 55, 'HP':                                                                                    |                   | Trainers like the    | 'prev': ['25', 'use                                               | [['Static',                                                                                                   | aw.githubusercontent                                 |                   | image mode=RGB     | 1.00884192e-01     | 2.66473174e-01    | 1.83678687e-01        |                             |
# |         | 'french':                                                            |                      | 60, 'Sp. Attack':                                                                                       |                   | way Pikachu looks,   | Thunder Stone']}                                                  | 'false'],                                                                                                     | .com/Purukitto/po...                                 |                   | size=100x100 at    | -7.27020875e-02    | -4.26447168e-02   | -5.76734021e-02       |                             |
# |         | 'Raichu'...                                                          |                      | 90,...                                                                                                  |                   | you ...              |                                                                   | ['Lightning Rod',                                                                                             |                                                      |                   | 0x7FD8490...       | 1.71526...         | 1.06502...        | 1.39014...            |                             |
# |         |                                                                      |                      |                                                                                                         |                   |                      |                                                                   | 'true...                                                                                                      |                                                      |                   |                    |                    |                   |                       |                             |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# |      10 | {'chinese':                                                          | ['Bug']              | {'Attack': 30,                                                                                          | Worm Pokémon      | Its body is soft and | {'next': [['11',                                                  | {'ability':                                                                                                   | {'hires': 'https://r                                 |                 9 | <PIL.Image.Image   | [ 4.44074512e-01   | [ 7.61542469e-02  | [ 2.60114372e-01      |                    0.648758 |
# |         | '绿毛虫', 'english':                                                 |                      | 'Defense': 35, 'HP':                                                                                    |                   | weak. In nature, its | 'Level 7']], 'prev':                                              | [['Shield Dust',                                                                                              | aw.githubusercontent                                 |                   | image mode=RGB     | -1.23782754e-01    | 8.82237554e-02    | -1.77794993e-02       |                             |
# |         | 'Caterpie',                                                          |                      | 45, 'Sp. Attack':                                                                                       |                   | perpetual fate ...   | None}                                                             | 'false'], ['Run                                                                                               | .com/Purukitto/po...                                 |                   | size=100x100 at    | -3.02484691e-01    | 3.60970348e-01    | 2.92428285e-02        |                             |
# |         | 'french': 'Chen...                                                   |                      | 20,...                                                                                                  |                   |                      |                                                                   | Away', 'true...                                                                                               |                                                      |                   | 0x7FD8490...       | -4.87557...        | -2.34479...       | -3.61018...           |                             |
# +---------+----------------------------------------------------------------------+----------------------+---------------------------------------------------------------------------------------------------------+-------------------+----------------------+-------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------+------------------------------------------------------+-------------------+--------------------+--------------------+-------------------+-----------------------+-----------------------------+
# (Showing first 5 rows)
